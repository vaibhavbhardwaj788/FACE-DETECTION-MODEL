# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
image = cv2.imread('d4153760-5f91-4d2d-b751-b77902eff4b0.jpg')

# %%
face = face_cascade.detectMultiScale(image,1.1,4)

# %%
for(x,y,w,h) in face:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

# %%
cv2.imwrite("face tetect.png",image)
# Out:
# True

# %%
plt.imshow(image)

# %%
+
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_25016\15193383.py", line 1
#     +
#      ^
# SyntaxError: invalid syntax
